# %%
fruits = ["Apple","Bananana", "mango", "Orange"]
print(fruits)
print(len(fruits))

fruits.append("Grapes")
more_fruits = ["Pineapples","Cherry"]
fruits.extend(more_fruits)
print("After extend: ", fruits)

print("First fruit : ", fruits[0])
print("last fruit : ", fruits[-1])
print(fruits[2:5])

fruits [1] ="Strawberry"
print("After updating index 1:", fruits)
fruits.remove("mango")
print("After remove Mango:", fruits)

removed_fruit = fruits.pop(2)
print(removed_fruit)
print("After pop:", fruits)

fruits.sort()
print("After sort:",fruits)
fruits.reverse()
print("After reverse:",fruits)

fruits.clear()
print(fruits)
# Out:
# ['Apple', 'Bananana', 'mango', 'Orange']
# 4
# After extend:  ['Apple', 'Bananana', 'mango', 'Orange', 'Grapes', 'Pineapples', 'Cherry']
# First fruit :  Apple
# last fruit :  Cherry
# ['mango', 'Orange', 'Grapes']
# After updating index 1: ['Apple', 'Strawberry', 'mango', 'Orange', 'Grapes', 'Pineapples', 'Cherry']
# After remove Mango: ['Apple', 'Strawberry', 'Orange', 'Grapes', 'Pineapples', 'Cherry']
# Orange
# After pop: ['Apple', 'Strawberry', 'Grapes', 'Pineapples', 'Cherry']
# After sort: ['Apple', 'Cherry', 'Grapes', 'Pineapples', 'Strawberry']
# After reverse: ['Strawberry', 'Pineapples', 'Grapes', 'Cherry', 'Apple']
# []

# %%
t=(1,2,3)
l=list(t)
l.append(4)
t=tuple(l)

print(t)
# Out:
# (1, 2, 3, 4)

# %%
# the * means the rest pf the items
a,b,*c =(1,2,3,4,5)
print("Expected Unpacking - First:", a,"Second:",b,"Rest:",c)
# Out:
# Expected Unpacking - First: 1 Second: 2 Rest: [3, 4, 5]

# %%
a,*b,c =(1,2,3,4,5)
print("Expected Unpacking - First:", a,"Second:",b,"Rest:",c)
# Out:
# Expected Unpacking - First: 1 Second: [2, 3, 4] Rest: 5

# %%
coordinates =(40.7128, -74.0060)
latitude, longitude = coordinates
print("Unpacked - latitude:", latitude, "Longitude:", longitude)
# Out:
# Unpacked - latitude: 40.7128 Longitude: -74.006

# %%
# A dictionary is written as a key-value pair.
# A key and its value is separated with a colon :
print("DICTIONARY OPERATIONS")
my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
print("Original Dictionary: ",my_dict)
# Out:
# DICTIONARY OPERATIONS
# Original Dictionary:  {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
# Accessing Values
print(my_dict['name'])
# print(my_dict['country'])
print(my_dict.get('city'))
# .get() is safer: returns None if key doesn't exist
print(my_dict.get('country')) # NONE
print(my_dict.get('country', 'USA'))

# Add a new key-value pair
my_dict['email'] = 'alice@example.com'
print("After adding email:", my_dict)
# Update an existing value
my_dict['age'] = 31
print("After updating age:", my_dict)
# Out:
# Alice
# New York
# None
# USA
# After adding email: {'name': 'Alice', 'age': 30, 'city': 'New York', 'email': 'alice@example.com'}
# After updating age: {'name': 'Alice', 'age': 31, 'city': 'New York', 'email': 'alice@example.com'}

# %% [markdown]
# **Function**

# %%
def add(num1,num2):
  result = num1 +num2
  return result
print(add(5,3))
# Out:
# 8

# %%
def default_check(x,y=5):
  print(x,y)
  return x+y
print(default_check(4,7))
# Out:
# 4 7
# 11
